# %%
#!pip install pandas 
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['gender'] # preferred
#df.gender
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %%
df['gender'][4]
# Out:
# 'Female'

# %%
df['gender'][2:5] # [2 5 [
# Out:
# 2      Male
# 3      Male
# 4    Female
# Name: gender, dtype: object

# %%
columns = ['gender','Partner']
df[columns]

# df[['gender','Partner']]
# Out:
#       gender Partner
# 0     Female     Yes
# 1       Male      No
# 2       Male      No
# 3       Male      No
# 4     Female      No
# ...      ...     ...
# 7038    Male     Yes
# 7039  Female     Yes
# 7040  Female     Yes
# 7041    Male     Yes
# 7042    Male      No
#
# [7043 rows x 2 columns]

# %%
df[columns][0:5] # [0 5 [
# Out:
#    gender Partner
# 0  Female     Yes
# 1    Male      No
# 2    Male      No
# 3    Male      No
# 4  Female      No

# %%
df.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
#
# [1 rows x 21 columns]

# %%
df.iloc[0,0:3] ## [rows,columns] --> by rows and column index
# Out:
# customerID       7590-VHVEG
# gender               Female
# SeniorCitizen           NaN
# Name: 0, dtype: object

# %%
df.loc[0,'gender'] ## [rows,columns] --> by rows and column names
# Out:
# 'Female'

# %% [markdown]
# ## Basic Descriptive Analysis

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.MonthlyCharges.mean()
# Out:
# 64.76169246059922

# %%
df.MonthlyCharges.median()
# Out:
# 70.35

# %%
df.MonthlyCharges.max()
# Out:
# 118.75

# %%
df.MonthlyCharges.min()
# Out:
# 18.25

# %%
df.MonthlyCharges.sum()
# Out:
# 456116.6

# %%
df.MonthlyCharges.std()
# Out:
# 30.09004709767854

# %%
df.MonthlyCharges.var()
# Out:
# 905.4109343405128

# %%
df.MonthlyCharges.count()
# Out:
# 7043

# %%
df.MonthlyCharges.mode()
# Out:
# 0    20.05
# dtype: float64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7000.000000  6896.000000     7043.000000   7043.000000
# mean        0.163143    33.041473       64.761692   2283.300440
# std         0.369522    24.382260       30.090047   2265.000258
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000    10.000000       35.500000    402.225000
# 50%         0.000000    30.000000       70.350000   1400.550000
# 75%         0.000000    56.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
cond = df.gender=='Male'
df[cond]
# cond
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male            NaN      No         No    34.0
# 2     3668-QPYBK   Male            NaN      No         No     2.0
# 3     7795-CFOCW   Male            NaN      No         No    45.0
# 6     1452-KIOVK   Male            NaN      No        Yes    22.0
# 9     6388-TABGU   Male            NaN      No        Yes    62.0
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male            0.0      No         No    38.0
# 7035  8456-QDAVC   Male            0.0      No         No    19.0
# 7038  6840-RESVB   Male            0.0     Yes        Yes    24.0
# 7041  8361-LTMKD   Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK   Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
df[df.gender=='Male'].MonthlyCharges.mean()
# Out:
# 64.32748241912773

# %%
df_male = df[df.gender=='Male']
df_male.head()
# Out:
#    customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE   Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK   Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW   Male            NaN      No         No    45.0           No
# 6  1452-KIOVK   Male            NaN      No        Yes    22.0          Yes
# 9  6388-TABGU   Male            NaN      No        Yes    62.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 6               Yes     Fiber optic             No  ...               No
# 9                No             DSL            Yes  ...               No
#
# ...

# %%
df_male.MonthlyCharges.median()
# Out:
# 70.1

# %%
df[(df.gender=='Male') & (df.Partner=='Yes') & (df.Dependents=='Yes')]#.MonthlyCharges.mean()
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 10    9763-GRSKD   Male            NaN     Yes        Yes    13.0
# 24    6322-HRPFA   Male            NaN     Yes        Yes    49.0
# 26    6467-CHFZW   Male            NaN     Yes        Yes    47.0
# 27    8665-UTDHZ   Male            NaN     Yes        Yes     NaN
# 40    8865-TNMNX   Male            NaN     Yes        Yes    10.0
# ...          ...    ...            ...     ...        ...     ...
# 6985  6967-PEJLL   Male            0.0     Yes        Yes    37.0
# 6992  0218-QNVAS   Male            0.0     Yes        Yes    71.0
# 7018  1122-JWTJW   Male            0.0     Yes        Yes     1.0
# 7020  9837-FWLCH   Male            0.0     Yes        Yes    12.0
# 7038  6840-RESVB   Male            0.0     Yes        Yes    24.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 10            Yes                No             DSL                  Yes  ...
# ...

# %%
df[(df.Partner=='Yes') | (df.Dependents=='Yes')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 6     1452-KIOVK    Male            NaN      No        Yes    22.0
# 8     7892-POOKP  Female            NaN     Yes         No    28.0
# 9     6388-TABGU    Male            NaN      No        Yes    62.0
# 10    9763-GRSKD    Male            NaN     Yes        Yes    13.0
# ...          ...     ...            ...     ...        ...     ...
# 7031  3605-JISKB    Male            1.0     Yes         No    55.0
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.groupby(['gender']).count()['customerID']
# Out:
# gender
# Female    3488
# Male      3555
# Name: customerID, dtype: int64

# %%
df.groupby(['gender']).mean()
# Out:
#            tenure  MonthlyCharges  TotalCharges
# gender
# Female  32.792882       65.204243   2283.191141
# Male    33.287197       64.327482   2283.407679

# %%
df.groupby(['gender','Partner']).mean()
# Out:
#                 SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# gender Partner
# Female No            0.178871  23.810148       63.874111   1627.546056
#        Yes           0.147795  42.204898       66.622630   2982.338744
# Male   No            0.136289  24.401922       60.058854   1544.081858
#        Yes           0.190504  42.538552       68.912398   3077.514352

# %%
df.groupby(['gender','Partner','Dependents']).mean()
# Out:
#                            SeniorCitizen     tenure  MonthlyCharges  \
# gender Partner Dependents
# Female No      No               0.192705  23.928040       64.566254
#                Yes              0.020833  22.471831       55.974138
#        Yes     No               0.260924  43.323750       73.907205
#                Yes              0.044470  41.180778       59.981540
# Male   No      No               0.151177  24.127796       61.372000
#                Yes              0.023474  26.504902       50.179861
#        Yes     No               0.332544  42.571090       75.993986
#                Yes              0.051103  42.506433       61.978002
#
#                            TotalCharges
# gender Partner Dependents
# Female No      No           1659.316616
#                Yes          1264.923448
#        Yes     No           3318.512174
#                Yes          2675.861268
# Male   No      No           1561.190769
#                Yes          1415.368981
# ...

# %%
df.groupby(['gender','Partner','Dependents']).count()['customerID']/df.shape[0]
# Out:
# gender  Partner  Dependents
# Female  No       No            0.234985
#                  Yes           0.020588
#         Yes      No            0.114298
#                  Yes           0.125373
# Male    No       No            0.230726
#                  Yes           0.030669
#         Yes      No            0.120403
#                  Yes           0.122959
# Name: customerID, dtype: float64

# %%
883/7043
# Out:
# 0.12537271049268778

# %%
df.shape[0]
# Out:
# 7043

# %%
df.SeniorCitizen.value_counts()
# Out:
# 0.0    5858
# 1.0    1142
# nan      43
# Name: SeniorCitizen, dtype: int64

# %%
df.SeniorCitizen
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 7038    0.0
# 7039    0.0
# 7040    0.0
# 7041    1.0
# 7042    0.0
# Name: SeniorCitizen, Length: 7043, dtype: float64

# %%
df['SeniorCitizen'] = df.SeniorCitizen.astype('str') # convert from original dtype to target dtype

# %%
'Null' != Null

# %%
df.isna().sum(axis=1) # get nan count per row
# Out:
# 0       2
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Length: 7043, dtype: int64

# %%
df.isna().sum() # get nan count per column
# Out:
# customerID            0
# gender                0
# SeniorCitizen        43
# Partner               0
# Dependents            0
# tenure              147
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            6896 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female           nan     Yes         No     NaN           No
# 1  5575-GNVDE    Male           nan      No         No    34.0          Yes
# 2  3668-QPYBK    Male           nan      No         No     2.0          Yes
# 3  7795-CFOCW    Male           nan      No         No    45.0           No
# 4  9237-HQITU  Female           nan      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.sort_values(by='TotalCharges',ascending=True)
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 1654  2967-MXRAV    Male           0.0     Yes        Yes     NaN
# 6489  9318-NKNFC    Male           0.0      No         No     1.0
# 1151  8992-CEUEN  Female           0.0      No         No     NaN
# 4939  9975-SKRNR    Male           0.0      No         No     1.0
# 583   1423-BMPBQ  Female           0.0     Yes        Yes     NaN
# ...          ...     ...           ...     ...        ...     ...
# 2187  8879-XUAHX    Male           0.0     Yes         No    71.0
# 5347  9788-HNGUT    Male           0.0     Yes         No    72.0
# 6768  9739-JLPQJ  Female           0.0     Yes        Yes    72.0
# 4586  7569-NMZYQ  Female           0.0     Yes        Yes    72.0
# 4610  2889-FPWRM    Male           0.0     Yes         No    72.0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1654          Yes            No              No  No internet service  ...
# ...

# %%
df.sort_values(by=['gender','Partner'],ascending=True)
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female           nan      No         No     2.0
# 5     9305-CDSKC  Female           nan      No         No     8.0
# 7     6713-OKOMC  Female           nan      No         No    10.0
# 16    8191-XWSZG  Female           nan      No         No    52.0
# 19    4183-MYFRB  Female           nan      No         No    21.0
# ...          ...     ...           ...     ...        ...     ...
# 7020  9837-FWLCH    Male           0.0     Yes        Yes    12.0
# 7024  7398-LXGYX    Male           0.0     Yes         No    44.0
# 7031  3605-JISKB    Male           1.0     Yes         No    55.0
# 7038  6840-RESVB    Male           0.0     Yes        Yes    24.0
# 7041  8361-LTMKD    Male           1.0     Yes         No     4.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 4             Yes                No     Fiber optic                   No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female           nan     Yes         No     NaN           No
# 1  5575-GNVDE    Male           nan      No         No    34.0          Yes
# 2  3668-QPYBK    Male           nan      No         No     2.0          Yes
# 3  7795-CFOCW    Male           nan      No         No    45.0           No
# 4  9237-HQITU  Female           nan      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
