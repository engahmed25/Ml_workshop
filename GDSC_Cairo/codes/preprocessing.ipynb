# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## 1- missing values
# - fill
#     - mean
#     - median
#     - mode == most frequent
#     - constant 0 - 1
#     - min
#     - max
#     - mean of each group --> clustering
#     - previous or next value --> time series dataset only
#     - random value
#     - prediction/classification
# - drop if missing values less than ....

# %%
df.isna().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen        43
# Partner               0
# Dependents            0
# tenure              147
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# customerID          0.000000
# gender              0.000000
# SeniorCitizen       0.610535
# Partner             0.000000
# Dependents          0.000000
# tenure              2.087179
# PhoneService        0.000000
# MultipleLines       0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingTV         0.000000
# StreamingMovies     0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# MonthlyCharges      0.000000
# TotalCharges        0.000000
# Churn               0.000000
# dtype: float64

# %%
df.dropna(subset=['tenure'])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# 5     9305-CDSKC  Female            NaN      No         No     8.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
#df.SeniorCitizen.fillna(0,inplace=True)
#df['SeniorCitizen'] = df.SeniorCitizen.fillna(0)
filler = df.SeniorCitizen.max()
df.SeniorCitizen.fillna(filler)
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 7038    0.0
# 7039    0.0
# 7040    0.0
# 7041    1.0
# 7042    0.0
# Name: SeniorCitizen, Length: 7043, dtype: float64

# %%
df.SeniorCitizen.mode().values[0]
# Out:
# 0.0

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#df.to_csv('new.csv')

# %% [markdown]
# ## 2- Categorical Features

# %%
df.gender.replace('Female',0,inplace=True)
df.gender.replace('Male',1,inplace=True)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG       0            NaN     Yes         No     NaN           No
# 1  5575-GNVDE       1            NaN      No         No    34.0          Yes
# 2  3668-QPYBK       1            NaN      No         No     2.0          Yes
# 3  7795-CFOCW       1            NaN      No         No    45.0           No
# 4  9237-HQITU       0            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#!pip install -U scikit-learn
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(df.Partner)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
le.transform(df.Partner)
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
le.fit_transform(df.Partner)
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
le.fit_transform(df.MultipleLines)
# Out:
# array([1, 0, 0, ..., 1, 2, 0])

# %%
le.classes_
# Out:
# array(['No', 'No phone service', 'Yes'], dtype=object)

# %%
partner_le       = LabelEncoder()
dependents_le    = LabelEncoder()
multiplelines_le = LabelEncoder()

df['Partner']       = partner_le.fit_transform(df.Partner)
df['Dependents']    = dependents_le.fit_transform(df.Dependents)
df['MultipleLines'] = multiplelines_le.fit_transform(df.MultipleLines)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0            NaN        1           0     NaN
# 1  5575-GNVDE       1            NaN        0           0    34.0
# 2  3668-QPYBK       1            NaN        0           0     2.0
# 3  7795-CFOCW       1            NaN        0           0    45.0
# 4  9237-HQITU       0            NaN        0           0     2.0
#
#   PhoneService  MultipleLines InternetService OnlineSecurity  ...  \
# 0           No              1             DSL             No  ...
# 1          Yes              0             DSL            Yes  ...
# 2          Yes              0             DSL            Yes  ...
# 3           No              1             DSL            Yes  ...
# 4          Yes              0     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
multiplelines_le.classes_
# Out:
# array(['No', 'No phone service', 'Yes'], dtype=object)

# %%
multiplelines_le.inverse_transform([0])
# Out:
# array(['No'], dtype=object)

# %% [markdown]
# ## 3- Scaling

# %%
400/410
# Out:
# 0.975609756097561

# %%
800/1000
# Out:
# 0.8

# %%
(x - x.min())/(x.max()-x.min())

# %%
(400 - 0)/ (410 - 0)
# Out:
# 0.975609756097561

# %%
(df.TotalCharges - df.TotalCharges.min()) / (df.TotalCharges.max() - df.TotalCharges.min())
# Out:
# 0       0.001275
# 1       0.215867
# 2       0.010310
# 3       0.210241
# 4       0.015330
#           ...
# 7038    0.227521
# 7039    0.847461
# 7040    0.037809
# 7041    0.033210
# 7042    0.787641
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
(df.MonthlyCharges - df.MonthlyCharges.min()) / (df.MonthlyCharges.max() - df.MonthlyCharges.min())
# Out:
# 0       0.115423
# 1       0.385075
# 2       0.354229
# 3       0.239303
# 4       0.521891
#           ...
# 7038    0.662189
# 7039    0.845274
# 7040    0.112935
# 7041    0.558706
# 7042    0.869652
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
(df.MonthlyCharges - df.MonthlyCharges.mean()) / (df.MonthlyCharges.std())
# Out:
# 0      -1.160241
# 1      -0.259611
# 2      -0.362635
# 3      -0.746482
# 4       0.197351
#           ...
# 7038    0.665945
# 7039    1.277443
# 7040   -1.168549
# 7041    0.320315
# 7042    1.358865
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(df[['TotalCharges','MonthlyCharges']])
# Out:
# array([[-0.99497138, -1.16032292],
#        [-0.17387565, -0.25962894],
#        [-0.96039939, -0.36266036],
#        ...,
#        [-0.85518222, -1.1686319 ],
#        [-0.87277729,  0.32033821],
#        [ 2.01391739,  1.35896134]])

# %%
y = m1x1+m2x2+m3x3+bias
